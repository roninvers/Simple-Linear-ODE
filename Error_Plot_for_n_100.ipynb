# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('euler_output_for_n_100.csv')

# %%
df.head()
# Out:
#       t   y_euler   y_exact     error
# 0  0.00  1.000000  1.000000  0.000000
# 1  0.05  1.000000  0.999979  0.000021
# 2  0.10  0.999938  0.999837  0.000100
# 3  0.15  0.999691  0.999459  0.000232
# 4  0.20  0.999145  0.998733  0.000412

# %%
# Plot 1: Error term (y_euler - y_exact) vs t
plt.figure(figsize=(8, 5))
plt.plot(df['t'], df['error'], label='Error (y_euler - y_exact)', color='red')
plt.xlabel('t')
plt.ylabel('Error')
plt.title('Error between Euler Numerical Solution and Analytical Solution')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Error Plot Description
# The error plot shows the difference between the Euler numerical solution and the analytical solution over time. As expected, the error remains relatively small and may oscillate or grow slowly depending on the step size and the nature of the ODE. A smaller error indicates better accuracy of the Euler method. If we decrease the step size (increase \( n \)), the error typically decreases, demonstrating the convergence of the numerical method to the exact solution.

# %%
# Plot 2: y_euler and y_exact vs t on the same plot
plt.figure(figsize=(8, 5))
plt.plot(df['t'], df['y_euler'], label='Euler Numerical Solution', color='blue')
plt.plot(df['t'], df['y_exact'], label='Analytical Solution', color='green', linestyle='dashed')
plt.xlabel('t')
plt.ylabel('y')
plt.title('Euler Numerical Solution and Analytical Solution vs Time')
plt.grid(True) # Helps to visualize better for smaller interval size.
plt.legend()
plt.show()

# %% [markdown]
# ## Euler Numerical Solution and Analytical Solution Plot Description
# This plot displays both the Euler numerical solution and the analytical solution for the differential equation as functions of time. The analytical solution serves as the exact reference, while the Euler solution provides an approximation. The closer the Euler curve is to the analytical curve, the more accurate the numerical method. Deviations between the two curves highlight the numerical error introduced by the discretization. Although the interval is split into 100 parts but we still see the two curves are not exactly overlapping as we can see the dotted lines for some portion, and is also clear from the error plot too.
